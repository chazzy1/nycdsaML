# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')
from scipy.stats import norm, skew
from scipy import stats
import numpy as np
import seaborn as sns

sns.set()

# %%
#Data loading
train_set = pd.read_csv('./data/train.csv')
test_set = pd.read_csv('./data/test.csv')

# %%
#Outlier

tmpDf = train_set.copy(deep=True)

numeric_columns = tmpDf.dtypes[tmpDf.dtypes != "object"].index
for col in numeric_columns:
    tmpDf[col].fillna(0, inplace=True)
    
z = np.abs(stats.zscore(tmpDf[numeric_columns]))


row, col = np.where(z > 5)


df = pd.DataFrame({"row":row, "col":col})
columns_with_outliers = {}

for i in zip(row,col):
    row, col = i
    col_name = tmpDf[numeric_columns].columns[col]
    columns_with_outliers.setdefault(col_name,[]).append(row)
    
print(columns_with_outliers)


rows_count = df.groupby(['row']).count()
rows_count[rows_count.col>2]

#plt.bar(rows_count.index, rows_count.col, width=10)
# Out:
# {'3SsnPorch': [5, 55, 129, 159, 182, 205, 237, 258, 280, 726, 744, 889, 941, 1080, 1161, 1181, 1346, 1437], 'KitchenAbvGr': [48, 809], 'LowQualFinSF': [51, 88, 170, 185, 197, 198, 263, 267, 406, 635, 729, 883, 1009, 1031, 1173, 1440], 'WoodDeckSF': [53, 1068, 1459], 'MasVnrArea': [58, 70, 115, 297, 691, 808, 1169], 'BsmtFinSF2': [113, 153, 271, 322, 470, 542, 764, 854, 924, 1253, 1299, 1369, 1418, 1458], 'ScreenPorch': [185, 359, 426, 625, 854, 907, 1328, 1386], 'EnclosedPorch': [197, 747, 1197], 'PoolArea': [197, 810, 1170, 1182, 1298, 1386, 1423], 'LotArea': [249, 313, 335, 451, 706, 1298], 'MiscVal': [346, 705, 1230], 'OpenPorchSF': [495, 523, 583, 854, 1328], '1stFlrSF': [496, 523, 1298], 'GrLivArea': [523, 691, 1182, 1298], 'BsmtHalfBath': [597, 954], 'BedroomAbvGr': [635], 'SalePrice': [691, 803, 898, 1169, 1182], 'LotFrontage': [934, 1298], 'BsmtFinSF1': [1298], 'TotalBsmtSF': [1298]}
# <BarContainer object of 90 artists>

# %%
plt.scatter(train_set['3SsnPorch'], train_set.SalePrice)

# %%
plt.scatter(train_set['KitchenAbvGr'], train_set.SalePrice)

# %%
plt.scatter(train_set['LowQualFinSF'], train_set.SalePrice)

# %%
plt.scatter(train_set['WoodDeckSF'], train_set.SalePrice)

# %%
plt.scatter(train_set['MasVnrArea'], train_set.SalePrice)

# %%
plt.scatter(train_set['BsmtFinSF2'], train_set.SalePrice)

# %%
plt.scatter(train_set['ScreenPorch'], train_set.SalePrice)

# %%
plt.scatter(train_set['EnclosedPorch'], train_set.SalePrice)

# %%
plt.scatter(train_set['PoolArea'], train_set.SalePrice)

# %%
plt.scatter(train_set['LotArea'], train_set.SalePrice)

# %%
plt.scatter(train_set['MasVnrArea'], train_set.SalePrice)

# %%
plt.scatter(train_set['MiscVal'], train_set.SalePrice)

# %%
plt.scatter(train_set['OpenPorchSF'], train_set.SalePrice)

# %%
plt.scatter(train_set['GrLivArea'], train_set.SalePrice)

# %%
plt.scatter(train_set['BsmtHalfBath'], train_set.SalePrice)

# %%
plt.scatter(train_set['BedroomAbvGr'], train_set.SalePrice)

# %%
plt.scatter(train_set['SalePrice'], train_set.SalePrice)

# %%
plt.scatter(train_set['LotFrontage'], train_set.SalePrice)

# %%
plt.scatter(train_set['BsmtFinSF1'], train_set.SalePrice)

# %%
plt.scatter(train_set['TotalBsmtSF'], train_set.SalePrice)

# %%
plt.scatter(train_set['1stFlrSF'], train_set.SalePrice)
